# %% [markdown]
# ## Use of Colaboratory:
# You can add text boxes or code blocks below or above each box.
#  * Code blocks are for running your code part. This can be done by pressing the triangular play button at the left side of the code block. It is important to run the code parts in the correct order.
# E.g. You cannot polish a chair leg if it does not exist.
#  * Text boxes are for documenting your work. It uses a so-called [markdown](https://www.markdownguide.org/basic-syntax/) syntax.
#
# Woah, woah woah... What is syntax???
# Every language needs a syntax. It describes according to what rules the computer can interpret what you are telling to it.
# E.g.: It is common amond a lot of language that you have to assigne a value to a variable by an '=' signe.
# Like this:

# %%
variable="value"

# %% [markdown]
# This is part of the code syntax, althaugh there are many other which will be presented in case of python.

# %% [markdown]
# Every OOP language has the followings:
#  * Classes: It is like a blueprint of your object you want to instantiate.
#  * Variables: As you have only two hands, your CPU has only 2/4/8/ect. cores. You are both limited. That is why variables comes into role. They hold an object in some kind of state of it. E.g. If it holds a chair leg, it might be just cut out, might be it is already polished or painted.
#  * Functions: These are well-separable code parts for making operations on different opjects.

# %%
# The simplest object in python can be 
# Integer number
integer=5
# A floating point number
floating=0.34
# A character
character='c'
# Or a series of characters called String
my_string="This is your first string to print!"

# You can call the print function, to visualize the content behind the name of the variable 
print(integer)
print(floating)
print(character)
print(my_string)
# Out:
# 5
# 0.34
# c
# This is your first string to print!

# %%
from openpyxl import load_workbook

# %%
workbook = load_workbook(filename="sample_data/test_01.xlsx")

# %%
workbook.sheetnames
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-acc3f167d41d> in <module>
# ----> 1 workbook["A1"]
#
# /usr/local/lib/python3.8/dist-packages/openpyxl/workbook/workbook.py in __getitem__(self, key)
#     286             if sheet.title == key:
#     287                 return sheet
# --> 288         raise KeyError("Worksheet {0} does not exist.".format(key))
#     289
#     290     def __delitem__(self, key):
#
# KeyError: 'Worksheet A1 does not exist.'

# %% [markdown]
# One of my colleague said: "For which there is no package in Python that's practically non-existent."
# That is very accurate. You have millions of kind of "workshops" mentioned in the previous lesson.
# To use them you need to write "import" and the name of the package:

# %%
import pandas as pd
